# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# Turn interactive plotting off
plt.ioff()

# pd.options.display.mpl_style='default'

# %%
# read a csv file to a dataframe; here we need to assign column names; we use species name for the row index

df = pd.read_csv(r'/data/shared/Big-Geodata-Processing-2021-1A/distributed_computing_machine_learning/Data/Iris/iris.dataComma.txt', 
                 index_col = 4,
                 header = None, 
                 names = 
                 ['sepal length', 
                  'sepal width', 
                  'petal length', 
                  'petal width', 
                  'species'])

df
# Out:
#                 sepal length  sepal width  petal length  petal width
# species
# Iris-setosa              5.1          3.5           1.4          0.2
# Iris-setosa              4.9          3.0           1.4          0.2
# Iris-setosa              4.7          3.2           1.3          0.2
# Iris-setosa              4.6          3.1           1.5          0.2
# Iris-setosa              5.0          3.6           1.4          0.2
# ...                      ...          ...           ...          ...
# Iris-virginica           6.7          3.0           5.2          2.3
# Iris-virginica           6.3          2.5           5.0          1.9
# Iris-virginica           6.5          3.0           5.2          2.0
# Iris-virginica           6.2          3.4           5.4          2.3
# Iris-virginica           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, Iris-setosa to Iris-virginica
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 5.9+ KB

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.shape
# Out:
# (150, 4)

# %%
list(df.columns)
# Out:
# ['sepal length', 'sepal width', 'petal length', 'petal width']

# %%
df.dtypes
# Out:
# sepal length    float64
# sepal width     float64
# petal length    float64
# petal width     float64
# dtype: object

# %%
list(df.index.unique())
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
df[0:3] #getting the first 3 rows of the data frame
# Out:
#              sepal length  sepal width  petal length  petal width
# species
# Iris-setosa           5.1          3.5           1.4          0.2
# Iris-setosa           4.9          3.0           1.4          0.2
# Iris-setosa           4.7          3.2           1.3          0.2

# %%
df.head(3) #getting the first 3 rows of the data frame
# Out:
#              sepal length  sepal width  petal length  petal width
# species
# Iris-setosa           5.1          3.5           1.4          0.2
# Iris-setosa           4.9          3.0           1.4          0.2
# Iris-setosa           4.7          3.2           1.3          0.2

# %%
 df[-3:150] #getting the last 3 rows of the data frame table
# Out:
#                 sepal length  sepal width  petal length  petal width
# species
# Iris-virginica           6.5          3.0           5.2          2.0
# Iris-virginica           6.2          3.4           5.4          2.3
# Iris-virginica           5.9          3.0           5.1          1.8

# %%
df.tail(3) #getting the last 3 rows of the data frame table
# Out:
#                 sepal length  sepal width  petal length  petal width
# species
# Iris-virginica           6.5          3.0           5.2          2.0
# Iris-virginica           6.2          3.4           5.4          2.3
# Iris-virginica           5.9          3.0           5.1          1.8

# %%
df['sepal length'][0:4] #getting the first 4 rows of the sepal length columns
# Out:
# species
# Iris-setosa    5.1
# Iris-setosa    4.9
# Iris-setosa    4.7
# Iris-setosa    4.6
# Name: sepal length, dtype: float64

# %%
df.mean(0) #getting the average value of each column
# Out:
# sepal length    5.843333
# sepal width     3.054000
# petal length    3.758667
# petal width     1.198667
# dtype: float64

# %%
df.median(0) #getting the median value of each column
# Out:
# sepal length    5.80
# sepal width     3.00
# petal length    4.35
# petal width     1.30
# dtype: float64

# %%
df.mode(0) #getting the mode value of each column
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           5.0          3.0           1.5          0.2

# %%
df.std(0) #getting the standard deviation value of each column
# Out:
# sepal length    0.828066
# sepal width     0.433594
# petal length    1.764420
# petal width     0.763161
# dtype: float64

# %%
df.min(0) #getting the minimal value of each column
# Out:
# sepal length    4.3
# sepal width     2.0
# petal length    1.0
# petal width     0.1
# dtype: float64

# %%
df.max(0) #getting the maximal value of each column
# Out:
# sepal length    7.9
# sepal width     4.4
# petal length    6.9
# petal width     2.5
# dtype: float64

# %%
df.var(0) #getting the variation value of each column
# Out:
# sepal length    0.685694
# sepal width     0.188004
# petal length    3.113179
# petal width     0.582414
# dtype: float64

# %%
df.quantile([0, 0.125, 0.25, 0.5, 0.625, 0.75, 1]) #getting the quantile value for each assign division
# Out:
#        sepal length  sepal width  petal length  petal width
# 0.000           4.3       2.0000          1.00          0.1
# 0.125           4.9       2.5625          1.40          0.2
# 0.250           5.1       2.8000          1.60          0.3
# 0.500           5.8       3.0000          4.35          1.3
# 0.625           6.1       3.1000          4.70          1.5
# 0.750           6.4       3.3000          5.10          1.8
# 1.000           7.9       4.4000          6.90          2.5

# %%
# get values for a single column
df['sepal length'].var()
# Out:
# 0.6856935123042505

# %%
df['sepal length'].hist(bins = 16)
plt.show() # I need it to show the plot

# %%
df.hist(bins = 16,
        color = 'r')

plt.show()

# %%
df['sepal length'].plot(kind = 'kde')

plt.show()

# %%
df.plot(kind = 'kde')
plt.show()

# %%
#here we get a Pandas.Series with the size for each species
a = df['petal length'].groupby(level = 'species').size() 
a
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: petal length, dtype: int64

# %%
a.plot(kind = 'pie',figsize = (5,5))
plt.show()

# %%
a.plot(kind = 'bar',
       figsize = (5,5), 
       rot = 15)

plt.show()

# %%
df.cov() #checking the covariance
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      0.685694    -0.039268      1.273682     0.516904
# sepal width      -0.039268     0.188004     -0.321713    -0.117981
# petal length      1.273682    -0.321713      3.113179     1.296387
# petal width       0.516904    -0.117981      1.296387     0.582414

# %%
df.corr() #checking the correlation
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
#  the stats of 'sepal length' of every species
a = df['sepal length'].groupby(level='species').describe()

print(a)
# Out:
#                  count   mean       std  min    25%  50%  75%  max
# species
# Iris-setosa       50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor   50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica    50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9

# %%
df.boxplot()
plt.show()

# %%
indexes = df.index
species = list(indexes.unique())
color_set = ('r', 'g', 'y')
color_list = [color_set[species.index(label)] for label in indexes]

df.plot(kind = 'scatter',
        x = 'petal length',
        y = 'petal width',
        c = color_list)

plt.show()

# %%
## C:\Users\kounadio\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 
# 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.

from pandas.plotting import scatter_matrix

scatter_matrix(df, alpha = 0.2, 
               figsize = (15,15),
               diagonal = 'kde',
               c = 'red')

plt.show()

# %%
# some fancy graphs

from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
x = list(df['sepal length'])
y = list(df['sepal width'])

ax.plot(x, y, zs = 0,
        zdir = 'z',
        marker = 'o')

plt.show()

# %%
plt.figure(figsize = (10, 10))
x = list(df['sepal length'])
y = list(df['sepal width'])
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.grid(True)
plt.hist2d(x, y)
plt.colorbar()
plt.show()

# %%
df.plot(kind = 'hexbin',
        x = 'sepal length',
        y = 'sepal width',
        gridsize = 30,
        figsize = (7, 7))

plt.show()

# %%
from pandas.plotting import andrews_curves

#here we load again the data because we need a column with the spacies name

data = pd.read_csv(r'/data/shared/Big-Geodata-Processing-2021-1A/distributed_computing_machine_learning/Data/Iris/iris.dataComma.txt',
                   header = None,
                   names = ['sepal length','sepal width','petal length','petal width','species'])

plt.figure(figsize = (7, 7),
          dpi = 133)

andrews_curves(data,'species', samples = 500)

plt.show()

# %%
from pandas.plotting import parallel_coordinates

plt.figure(figsize = (7, 7))
parallel_coordinates(data, 'species')

plt.savefig(r'private/Tutorial/parallel.png', format = 'png')

plt.show()
